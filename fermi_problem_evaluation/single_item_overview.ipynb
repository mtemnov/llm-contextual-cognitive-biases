# %%
import sys
import os

print(os.getcwd())
notebook_dir = os.path.abspath("")
sys.path.append('..')
import argparse
import json
import pickle
import os
import pandas as pd
import numpy as np
import math
import re
import matplotlib.pyplot as plt
from pandas.plotting import table
from utils import *

# %%
target_questions = pd.read_csv("./experiment_data/target_questions.csv")

context_questions = pd.read_csv("./experiment_data/generated_context_questions.csv")

target_data = pd.DataFrame()
for root, dirs, files in os.walk("./results/"):
    for file in files:
        if file.endswith("target_responses.csv"):
            file_path = os.path.join(root, file)
            if "llama_context" not in file_path and "gemini" not in file_path and "assumptions" not in file_path:
                new_data = pd.read_csv(file_path)
                target_data = pd.concat([target_data, new_data], ignore_index=True)

print(target_data.shape, target_data.columns)

context_data = pd.DataFrame()
for root, dirs, files in os.walk("./results/"):
    for file in files:
        if file.endswith("simple_responses.csv"):
            file_path = os.path.join(root, file)
            new_data = pd.read_csv(file_path)
            context_data = pd.concat([context_data, new_data], ignore_index=True)

print(context_data.shape, context_data.columns)
# Out:
# (56000, 9) Index(['target_id', 'sample', 'model', 'context', 'context_prompt',
#        'context_bias', 'target_prompt', 'experiment_type', 'response'],
#       dtype='object')
# (2600, 8) Index(['target_id', 'sample', 'model', 'context', 'context_prompt',
#        'context_bias', 'experiment_type', 'response'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %%
answer_df = pd.read_pickle("saved_states/processed_answers.pkl")
conversion_df = pd.read_pickle("saved_states/conversions.pkl")

# %%
print(answer_df.shape, answer_df.head(2))
# Out:
# (56000, 11)    target_id  sample          model      context context_prompt  \
# 0          0       0  gpt-3.5-turbo  gpt-4-turbo         simple
# 1          0       1  gpt-3.5-turbo  gpt-4-turbo         simple
#
#     context_bias target_prompt experiment_type        number  \
# 0  answer_anchor    onlyanswer        decrease  3.000000e+06
# 1  answer_anchor    onlyanswer        decrease  3.000000e+09
#
#    order_of_magnitude comment
# 0                 6.0    None
# 1                 9.0    None

# %% [markdown]
# ## Filter out not usable answers

# %%
no_answer = answer_df[answer_df["comment"].notnull() & (answer_df["comment"] != "unit_converted")]
print(len(no_answer))#, no_answer)

no_answer_cats = no_answer.groupby("comment")
for key, val_group in no_answer_cats:
    print(key, len(val_group))
# Out:
# 1129
# no_answer 293
# no_concrete_answer 306
# percentage 14
# range 512
# unit_not_convertible 4

# %%
filtered_answers = answer_df[~answer_df.index.isin(no_answer.index)]

len(filtered_answers)
# Out:
# 54871

# %% [markdown]
# ## Group values by question setting combination

# %%
oom_df = pd.read_pickle("saved_states/results_oom_df.pkl")
num_df = pd.read_pickle("saved_states/results_num_df.pkl")

# %% [markdown]
# ## Print single items

# %%
def print_data(model, target_id, context, exp_type, prompt, sample=None):
    model = models[model]
    context = context_biases[context]
    exp_type = exp_types[exp_type]
    prompt = prompts[prompt]

    print("EXPERIMENT", target_id, model, context, prompt, exp_type)

    fp = target_questions[target_questions["id"] == target_id].iloc[0]["question"]
    print("TARGET QUESTION", fp)

    baseline_stats = oom_df[(oom_df["model"] == model) &
                       (oom_df["target_id"] == target_id) &
                       (oom_df["context_bias"] == "none") &
                       (oom_df["experiment_type"] == "neutral") &
                       (oom_df["target_prompt"] == prompt)].iloc[0]
    
    baseline_answers = answer_df[(answer_df["model"] == model) &
                           (answer_df["target_id"] == target_id) &
                           (answer_df["context_bias"] == "none") &
                           (answer_df["experiment_type"] == "neutral") &
                           (answer_df["target_prompt"] == prompt)]
    baseline_med_answer = None
    
    if sample != None:
        baseline_len = sample
    else:
        baseline_len = int(baseline_stats["num_valid_answers"]/2)

    baseline_answers = baseline_answers.sort_values(by="number").reset_index(drop=True)
    baseline_med_id = baseline_answers.loc[baseline_len, "sample"]

    baseline_med_answer = target_data[(target_data["model"] == model) &
                            (target_data["target_id"] == target_id) &
                            (target_data["context_bias"] == "none") &
                            (target_data["experiment_type"] == "neutral") &
                            (target_data["target_prompt"] == prompt) &
                            (target_data["sample"] == baseline_med_id)].iloc[0]

    print("BASELINE -------------------------------------------")
    print(baseline_stats[["50%", "unique", "std", "target_id"]])
    print(baseline_answers[["sample", "number", "order_of_magnitude"]])
    print(baseline_med_answer["response"])

    for exp in ["decrease", "increase", "neutral"]:
        try:
            context_question = context_questions[(context_questions["target_id"] == target_id) &
                                                (context_questions["bias"] == context) &
                                                (context_questions["experiment_type"] == exp)].iloc[0]["question"]

            exp_stats = oom_df[(oom_df["model"] == model) &
                            (oom_df["target_id"] == target_id) &
                            (oom_df["context_bias"] == context) &
                            (oom_df["experiment_type"] == exp) &
                            (oom_df["target_prompt"] == prompt)].iloc[0]
            
            exp_answers = answer_df[(answer_df["model"] == model) &
                                (answer_df["target_id"] == target_id) &
                                (answer_df["context_bias"] == context) &
                                (answer_df["experiment_type"] == exp) &
                                (answer_df["target_prompt"] == prompt)]
            
            exp_med_answer = None

            if sample != None:
                exp_len = sample
            else:
                exp_len = int(exp_stats["num_valid_answers"]/2)

            exp_answers = exp_answers.sort_values(by="number").reset_index(drop=True)
            exp_med_id = exp_answers.loc[exp_len, "sample"]
            print(exp_len, exp_med_id)
            exp_med_answer = target_data[(target_data["model"] == model) &
                                    (target_data["target_id"] == target_id) &
                                    (target_data["context_bias"] == context) &
                                    (target_data["experiment_type"] == exp) &
                                    (target_data["target_prompt"] == prompt) &
                                    (target_data["sample"] == exp_med_id)].iloc[0]
                
            exp_context = context_data[(context_data["model"] == model) &
                                        (context_data["target_id"] == target_id) &
                                        (context_data["context_bias"] == context) &
                                        (context_data["experiment_type"] == exp)].iloc[0]
        
            if exp_type == "both" or exp == exp_type:
                print(exp + " -------------------------------------------")
                print(exp_stats[["50%", "unique", "std", "target_id"]])
                print(exp_answers[["sample", "number", "order_of_magnitude"]])
                print(context_question)
                print(exp_context["response"])
                print(exp_med_answer["response"])
        except:
            pass

exp_types = {
    0: "decrease",
    1: "increase",
    2: "both",
    3: "neutral"
}

context_biases = {
    0: "general",
    1: "question_anchor",
    2: "answer_anchor",
    3: "implicit_confirmation",
    4: "explicit_confirmation",
    5: "availability",
    6: "control"
}

models = {
    0: "gpt-3.5-turbo",
    1: "gpt-4-turbo",
    2: "gpt-4o",
    3: "Llama-3-70b-chat-hf"
}

prompts = {
    0: "onlyanswer",
    1: "reasoning"
}

# %%
print_data(
    2, # model
    48, # qid
    6, # context
    2, # exp_type
    1, # prompt
    4 ) # sample
# Out:
# EXPERIMENT 48 gpt-4o control reasoning both
# TARGET QUESTION How much would a newly-discovered unreleased Beatles album sell for?
# BASELINE -------------------------------------------
# 50%               6.0
# unique              3
# std          0.471405
# target_id          48
# Name: 4151, dtype: object
#    sample      number  order_of_magnitude
# 0       5    150000.0                 5.0
# 1       1   2000000.0                 6.0
# 2       0   5000000.0                 6.0
# 3       2   5000000.0                 6.0
# 4       3   5000000.0                 6.0
# 5       4   5000000.0                 6.0
# 6       6   5000000.0                 6.0
# 7       7   5000000.0                 6.0
# 8       9   5000000.0                 6.0
# 9       8  10000000.0                 7.0
# Reasoning:
# 1. The Beatles are one of the most iconic and influential bands in music history.
# 2. Unreleased music from legendary artists can have immense value.
# 3. Previous Beatles memorabilia and rare items have sold for millions.
# 4. The market for rare music items shows high demand and willingness to pay premium prices.
# 5. Estimating based on other high-ticket music memorabilia sales.
#
# Answer: 5000000 USD
# 4 4
# neutral -------------------------------------------
# 50%               7.0
# unique              2
# std          0.421637
# target_id          48
# Name: 4162, dtype: object
#    sample      number  order_of_magnitude
# 0       0   5000000.0                 6.0
# 1       1   5000000.0                 6.0
# 2       2  10000000.0                 7.0
# 3       3  10000000.0                 7.0
# 4       4  10000000.0                 7.0
# 5       5  10000000.0                 7.0
# 6       6  10000000.0                 7.0
# 7       7  10000000.0                 7.0
# 8       8  10000000.0                 7.0
# 9       9  10000000.0                 7.0
# Who are the Beatles?
# The Beatles were a British rock band formed in Liverpool in 1960, consisting of John Lennon, Paul McCartney, George Harrison, and Ringo Starr. They are widely regarded as one of the most influential bands in the history of music, known for their innovative songwriting, harmonious vocals, and cultural impact. The Beatles achieved unprecedented success with hits like "Hey Jude," "Let It Be," and "Yesterday," and they played a significant role in shaping the music and culture of the 1960s.
# Reasoning:
# 1. The Beatles are one of the most iconic and influential bands in music history.
# 2. Memorabilia and rare items related to The Beatles can sell for millions.
# 3. A previously unreleased album would be a highly significant and rare find.
# 4. High-profile auctions for similar rare albums and items have fetched millions.
#
# Answer: $10,000,000 USD

# %% [markdown]
# Example: print all System 2 exceptions (OOM deviation > 1 despite high baseline persistence)

# %%
eval = 0

if eval == 0:
    for (qid, bias) in [(0, 'explicit_confirmation'), (3, 'general'), (27, 'answer_anchor'), (27, 'explicit_confirmation'), (32, 'implicit_confirmation')]:#[35, 44, 11, 21, 26, 43, 1, 45, 18]:#[43, 11, 35, 16, 47, 29, 18, 37, 41, 45, 4, 1]:
        print_data(0, qid, [key for (key, val) in context_biases.items() if val == bias][0], 2, 1)
        print("________________________________________________\n")
if eval == 1:
    for (qid, bias) in [(5, 'availability'), (9, 'answer_anchor'), (27, 'answer_anchor'), (27, 'explicit_confirmation'), (27, 'implicit_confirmation'), (38, 'question_anchor'), (46, 'general')]:#[35, 27, 49, 42, 48, 41, 11, 34]:
        print_data(1, qid, [key for (key, val) in context_biases.items() if val == bias][0], 2, 1)
        print("________________________________________________\n")
if eval == 2:
    for (qid, bias) in [(3, 'availability'), (3, 'general'), (12, 'availability'), (12, 'general'), (12, 'question_anchor'), (21, 'availability'), (21, 'question_anchor'), (27, 'answer_anchor'), (27, 'availability'), (37, 'question_anchor'), (38, 'question_anchor'), (38, 'explicit_confirmation'), (40, 'question_anchor'), (40, 'explicit_confirmation'), (48, 'availability'), (48, 'general'), (48, 'implicit_confirmation')]:#[40, 4, 42, 16]:#, 36, 5, 37, 41, 44, 2, 11, 12, 13, 19, 15, 39]:
        print_data(2, qid, [key for (key, val) in context_biases.items() if val == bias][0], 2, 1)
        print("________________________________________________\n")
if eval == 3:
    for (qid, bias) in [(11, 'question_anchor'), (11, 'implicit_confirmation'), (12, 'implicit_confirmation'), (18, 'answer_anchor'), (18, 'general'), (18, 'question_anchor'), (18, 'explicit_confirmation'), (27, 'explicit_confirmation'), (30, 'availability'), (30, 'general'), (30, 'implicit_confirmation'), (40, 'availability'), (40, 'general'), (40, 'implicit_confirmation'), (49, 'question_anchor')]:#[35, 44, 39, 43, 42]:#, 40, 13, 21, 4, 5, 46, 8, 41]:
        print_data(3, qid, [key for (key, val) in context_biases.items() if val == bias][0], 2, 1)
        print("________________________________________________\n")
# Out:
# EXPERIMENT 0 gpt-3.5-turbo explicit_confirmation reasoning both
# TARGET QUESTION How many people in the world are talking on their cell phones at this instant?
# BASELINE -------------------------------------------
# 50%               9.0
# unique              2
# std          0.421637
# target_id           0
# Name: 14, dtype: object
#    sample        number  order_of_magnitude
# 0       1  4.740000e+08                 8.0
# 1       8  5.530000e+08                 8.0
# 2       9  1.000000e+09                 9.0
# 3       6  2.500000e+09                 9.0
# 4       3  2.600000e+09                 9.0
# 5       5  3.654000e+09                 9.0
# 6       7  3.696000e+09                 9.0
# 7       4  4.740000e+09                 9.0
# 8       0  5.530000e+09                 9.0
# 9       2  5.530000e+09                 9.0
# Reasoning:
# 1. There are approximately 7.9 billion people in the world.
# 2. According to Statista, about 5.22 billion people worldwide use a mobile phone.
# 3. Assuming that at any given moment, a significant portion of the population is using their cell phones, let's estimate that 70% of mobile phone users are talking on their cell phones.
# 4. Therefore, the estimated number of people talking on their cell phones at this instant would be 70% of 5.22 billion.
#
# Answer: 3,654,000,000 people.
# 5 2
# decrease -------------------------------------------
# 50%               9.0
# unique              2
# std          0.316228
# target_id           0
# Name: 19, dtype: object
#    sample        number  order_of_magnitude
# 0       3  4.333333e+08                 8.0
# 1       9  1.420000e+09                 9.0
# 2       4  2.500000e+09                 9.0
# 3       6  2.600000e+09                 9.0
# 4       8  2.650000e+09                 9.0
# 5       2  3.000000e+09                 9.0
# 6       1  3.690000e+09                 9.0
# 7       0  5.000000e+09                 9.0
# 8       5  5.140000e+09                 9.0
# 9       7  8.000000e+09                 9.0
# Was there a significant global decrease in cell phone usage recently?
# No, there has not been a significant global decrease in cell phone usage recently.
# Reasoning:
# 1. As of 2021, there are approximately 8 billion people in the world.
# 2. According to various studies, around 5 billion people worldwide own a mobile phone.
# 3. Assuming that a significant percentage of mobile phone owners are actively talking on their phones at any given moment, let's estimate that 60% of mobile phone owners are currently talking on their phones.
#
# Answer: 3 billion people
# 5 4
# increase -------------------------------------------
# 50%               8.0
# unique              2
# std          0.316228
# target_id           0
# Name: 20, dtype: object
#    sample        number  order_of_magnitude
# 0       7  1.580000e+08                 8.0
# 1       5  4.740000e+08                 8.0
# 2       8  5.000000e+08                 8.0
# 3       6  5.200000e+08                 8.0
# 4       0  5.270000e+08                 8.0
# 5       4  5.280000e+08                 8.0
# 6       1  5.293000e+08                 8.0
# 7       2  5.530000e+08                 8.0
# 8       3  7.900000e+08                 8.0
# 9       9  1.108000e+09                 9.0
# Do most people use their cell phones primarily for talking?
# No, most people use their cell phones primarily for texting, browsing the internet, and using social media.
# Reasoning:
# 1. There are approximately 7.9 billion people in the world.
# 2. Based on global statistics, around 5.28 billion people are estimated to have mobile phones.
# 3. Assuming a portion of these people are currently talking on their cell phones, let's estimate that 10% of mobile phone users are actively talking at any given moment.
#
# Answer: 528 million people
# ________________________________________________
#
# EXPERIMENT 3 gpt-3.5-turbo general reasoning both
# TARGET QUESTION How many students are there in North America?
# BASELINE -------------------------------------------
# 50%          8.0
# unique         1
# std          0.0
# target_id      3
# Name: 98, dtype: object
#    sample       number  order_of_magnitude
# 0       7  108700000.0                 8.0
# 1       0  115800000.0                 8.0
# 2       2  115800000.0                 8.0
# 3       3  115800000.0                 8.0
# 4       4  115800000.0                 8.0
# 5       5  115800000.0                 8.0
# 6       6  115800000.0                 8.0
# 7       8  115800000.0                 8.0
# 8       1  220000000.0                 8.0
# 9       9          NaN                 NaN
# Reasoning:
# 1. North America consists of 23 countries, including the United States, Canada, Mexico, and various islands in the Caribbean.
# 2. According to recent data, the combined population of North America is approximately 579 million.
# 3. Assuming a rough estimate that about 20% of the population in North America are students (from primary school to university level), we can make a reasonable estimate.
#
# Answer: 115.8 million students
# 5 0
# decrease -------------------------------------------
# 50%               8.0
# unique              2
# std          0.483046
# target_id           3
# Name: 105, dtype: object
#    sample       number  order_of_magnitude
# 0       4   28950000.0                 7.0
# 1       5   65000000.0                 7.0
# 2       8   99700000.0                 7.0
# 3       7  100000000.0                 8.0
# 4       3  104400000.0                 8.0
# 5       0  115800000.0                 8.0
# 6       1  115800000.0                 8.0
# 7       9  115800000.0                 8.0
# 8       6  116000000.0                 8.0
# 9       2  127000000.0                 8.0
# How many students are there in your local school district?
# There are approximately 10,000 students in my local school district.
# Reasoning:
# 1. The population of North America is approximately 579 million people.
# 2. Assuming an average of 20% of the population is students (from kindergarten to college), that would be around 115.8 million students in North America.
# Answer: 115.8 million students.
# 5 5
# increase -------------------------------------------
# 50%               7.0
# unique              2
# std          0.483046
# target_id           3
# Name: 106, dtype: object
#    sample       number  order_of_magnitude
# 0       2   23881700.0                 7.0
# 1       0   27000000.0                 7.0
# 2       3   30000000.0                 7.0
# 3       6   30000000.0                 7.0
# 4       7   46000000.0                 7.0
# 5       5   50000000.0                 7.0
# 6       8   60000000.0                 7.0
# 7       9  100000000.0                 8.0
# 8       1  115800000.0                 8.0
# 9       4  173700000.0                 8.0
# How many universities are there in North America?
# There are approximately 4,700 universities in North America.
# Reasoning:
# 1. According to the National Center for Education Statistics, there were approximately 21 million students enrolled in degree-granting postsecondary institutions in the United States in the 2020-2021 academic year.
# 2. Canada has a population of around 38 million, and a significant portion of this population is enrolled in postsecondary education.
# 3. Mexico has a population of over 126 million, with a large number of students enrolled in universities and colleges.
# 4. Considering the large populations of all three countries and the high enrollment rates in postsecondary education, we can estimate that there are around 50 million students in North America.
#
# Answer:
# Approximately 50 million students.
# ________________________________________________
#
# EXPERIMENT 27 gpt-3.5-turbo answer_anchor reasoning both
# TARGET QUESTION How much fish do humans consume per year?
# BASELINE -------------------------------------------
# 50%          11.0
# unique          1
# std           0.0
# target_id      27
# Name: 767, dtype: object
#    sample        number  order_of_magnitude
# 0       1  1.580000e+11                11.0
# 1       2  1.580000e+11                11.0
# 2       4  1.580000e+11                11.0
# 3       6  1.580000e+11                11.0
# 4       7  1.580000e+11                11.0
# 5       8  1.580000e+11                11.0
# 6       3  1.599000e+11                11.0
# 7       0  1.603700e+11                11.0
# 8       9  1.603700e+11                11.0
# 9       5  1.620000e+11                11.0
# Reasoning:
# 1. According to data from the Food and Agriculture Organization (FAO), the average global per capita fish consumption is around 20 kg per year.
# 2. The current global population is approximately 7.9 billion people.
# 3. To find the total fish consumption per year, we can multiply the average per capita consumption by the global population.
#
# Answer: 158,000,000,000 kg/year
# 5 5
# decrease -------------------------------------------
# 50%             11.0
# unique             2
# std          4.21637
# target_id         27
# Name: 768, dtype: object
#    sample        number  order_of_magnitude
# 0       1  2.000000e+01                 1.0
# 1       4  2.000000e+01                 1.0
# 2       0  1.580000e+11                11.0
# 3       2  1.580000e+11                11.0
# 4       3  1.580000e+11                11.0
# 5       5  1.580000e+11                11.0
# 6       6  1.580000e+11                11.0
# 7       7  1.580000e+11                11.0
# 8       8  1.580000e+11                11.0
# 9       9  1.580000e+11                11.0
# How much fish does a small cat consume per year?
# A small cat consumes approximately 30-35 pounds of fish per year.
# Reasoning:
# 1. The average global per capita fish consumption is around 20 kg per year.
# 2. There are approximately 7.9 billion people in the world.
# 3. Multiply the average per capita consumption by the global population to estimate total fish consumption.
#
# Answer:
# Total fish consumption by humans per year is approximately 158 billion kg/year.
# 5 7
# increase -------------------------------------------
# 50%               1.0
# unique              2
# std          4.830459
# target_id          27
# Name: 769, dtype: object
#    sample        number  order_of_magnitude
# 0       9  1.900000e+01                 1.0
# 1       0  2.000000e+01                 1.0
# 2       5  2.000000e+01                 1.0
# 3       8  2.000000e+01                 1.0
# 4       2  2.020000e+01                 1.0
# 5       7  2.030000e+01                 1.0
# 6       1  2.100000e+01                 1.0
# 7       3  1.580000e+11                11.0
# 8       4  1.580000e+11                11.0
# 9       6  1.580000e+11                11.0
# How many liters of water does the average person drink per year?
# The average person drinks approximately 730 liters of water per year.
# Reasoning:
# 1. According to the United Nations Food and Agriculture Organization, the global average fish consumption per capita is around 20.3 kilograms per year.
# 2. This includes both freshwater and marine fish consumption.
# 3. Fish consumption varies among different countries and regions due to cultural, economic, and dietary factors.
#
# Answer:
# The average human consumes approximately 20.3 kilograms of fish per year.
# ________________________________________________
#
# EXPERIMENT 27 gpt-3.5-turbo explicit_confirmation reasoning both
# TARGET QUESTION How much fish do humans consume per year?
# BASELINE -------------------------------------------
# 50%          11.0
# unique          1
# std           0.0
# target_id      27
# Name: 767, dtype: object
#    sample        number  order_of_magnitude
# 0       1  1.580000e+11                11.0
# 1       2  1.580000e+11                11.0
# 2       4  1.580000e+11                11.0
# 3       6  1.580000e+11                11.0
# 4       7  1.580000e+11                11.0
# 5       8  1.580000e+11                11.0
# 6       3  1.599000e+11                11.0
# 7       0  1.603700e+11                11.0
# 8       9  1.603700e+11                11.0
# 9       5  1.620000e+11                11.0
# Reasoning:
# 1. According to data from the Food and Agriculture Organization (FAO), the average global per capita fish consumption is around 20 kg per year.
# 2. The current global population is approximately 7.9 billion people.
# 3. To find the total fish consumption per year, we can multiply the average per capita consumption by the global population.
#
# Answer: 158,000,000,000 kg/year
# 5 4
# decrease -------------------------------------------
# 50%          11.0
# unique          1
# std           0.0
# target_id      27
# Name: 772, dtype: object
#    sample        number  order_of_magnitude
# 0       5  1.558000e+11                11.0
# 1       2  1.560000e+11                11.0
# 2       6  1.560000e+11                11.0
# 3       8  1.560000e+11                11.0
# 4       3  1.580000e+11                11.0
# 5       4  1.580000e+11                11.0
# 6       0  1.620000e+11                11.0
# 7       1  1.629500e+11                11.0
# 8       7  1.629500e+11                11.0
# 9       9  1.629500e+11                11.0
# Is it true that most people are trying to reduce their fish consumption to save the environment?
# Yes, it is true that many people are trying to reduce their fish consumption to help protect the environment and marine ecosystems.
# Reasoning:
# 1. According to the Food and Agriculture Organization (FAO), the global average fish consumption per capita is around 20 kg per year.
# 2. As of 2021, the world population is approximately 7.9 billion.
# 3. To find the total fish consumption per year, we multiply the global average fish consumption per capita by the world population.
#
# Answer:
# 158 billion kg/year
# 4 5
# increase -------------------------------------------
# 50%              10.0
# unique              3
# std          5.174725
# target_id          27
# Name: 773, dtype: object
#    sample        number  order_of_magnitude
# 0       1  1.950000e+01                 1.0
# 1       3  2.000000e+01                 1.0
# 2       7  2.020000e+01                 1.0
# 3       4  2.100000e+01                 1.0
# 4       5  6.178000e+10                10.0
# 5       9  1.575600e+11                11.0
# 6       0  1.595800e+11                11.0
# 7       2  1.595800e+11                11.0
# 8       8  1.595800e+11                11.0
# 9       6           NaN                 NaN
# Does the average person consume a lot of fish each year?
# The average person consumes about 20.2 kilograms (or 44.5 pounds) of fish per year.
# Reasoning:
# 1. The global average annual fish consumption per person is approximately 20.2 kilograms.
# 2. The global population is approximately 7.9 billion people.
#
# Answer:
# 61,780,000,000 kg/year
# ________________________________________________
#
# EXPERIMENT 32 gpt-3.5-turbo implicit_confirmation reasoning both
# TARGET QUESTION How long would it take to drive on the entirety of every road in Europe at the posted speed limit?
# BASELINE -------------------------------------------
# 50%               5.0
# unique              2
# std          0.316228
# target_id          32
# Name: 907, dtype: object
#    sample    number  order_of_magnitude
# 0       9   18000.0                 4.0
# 1       4  110000.0                 5.0
# 2       6  110000.0                 5.0
# 3       5  132000.0                 5.0
# 4       1  140000.0                 5.0
# 5       3  142400.0                 5.0
# 6       2  174000.0                 5.0
# 7       0  200000.0                 5.0
# 8       8  200000.0                 5.0
# 9       7  264000.0                 5.0
# Reasoning:
# 1. The total road network in Europe is estimated to be around 7.12 million kilometers.
# 2. Assuming an average speed limit of 50 km/h on these roads.
# 3. To calculate the total time, divide the total road length by the average speed limit.
#
# Answer:
# Total time = 7.12 million km / 50 km/h = 142,400 hours.
# 5 3
# decrease -------------------------------------------
# 50%               4.0
# unique              4
# std          1.178511
# target_id          32
# Name: 919, dtype: object
#    sample    number  order_of_magnitude
# 0       8     185.0                 2.0
# 1       9     250.0                 2.0
# 2       5     285.0                 2.0
# 3       6    2000.0                 3.0
# 4       0   46364.0                 4.0
# 5       3   56666.0                 4.0
# 6       1   72000.0                 4.0
# 7       2   84000.0                 4.0
# 8       4  111111.0                 5.0
# 9       7  570000.0                 5.0
# Why is the proportion of motorways high on European roads?
# The proportion of motorways is high on European roads because they are designed to efficiently handle high volumes of traffic, improve safety, and facilitate long-distance travel across countries and regions. Additionally, motorways are an essential component of the European transportation network, connecting major cities and economic centers.
# Reasoning:
# 1. Europe has a total road network of approximately 5.1 million kilometers.
# 2. The average speed limit on European roads is around 50-130 km/h.
# 3. To calculate the total time needed, we will take an average speed of 90 km/h.
#
# Answer:
# It would take approximately 56,666 hours to drive on the entirety of every road in Europe at the posted speed limit.
# 4 7
# increase -------------------------------------------
# 50%               5.0
# unique              3
# std          1.224745
# target_id          32
# Name: 920, dtype: object
#    sample       number  order_of_magnitude
# 0       0      73000.0                 4.0
# 1       8      73000.0                 4.0
# 2       4      84615.0                 4.0
# 3       2     125000.0                 5.0
# 4       7     150000.0                 5.0
# 5       6     172000.0                 5.0
# 6       5     414000.0                 5.0
# 7       9     900000.0                 5.0
# 8       3  132000000.0                 8.0
# 9       1          NaN                 NaN
# Why is the speed limit very low on most European roads?
# The speed limit on most European roads is low to prioritize safety and reduce accidents, especially in densely populated areas with narrow streets and heavy traffic.
# Reasoning: 1. Estimate the total road network in Europe. 2. Calculate the average speed limit across European roads. 3. Use the total road length and average speed limit to determine the time needed.
# Answer: Approximately 150,000 hours.
# ________________________________________________
